# %%
#!/usr/bin/env python
###################################
#                                 #
# File coded by: Robert J. Koch   #
#                                 #
###################################
#
# Example 2, Refining PDF from nanocrystalline platinum to obtain
# an estimate for the nanoparticle (NP) size, as well as the atomic structure.
#
# This Diffpy-CMI script will carry out a structural refinement of a measured
# PDF from nanocrystalline platinum.  It is explicitly uses the instrumental parameters
# found in tutorial 1, and requires that the output files of this tutorial
# are present in a specific location.
#
# Comments in this Example will be less verbose than in Example 1. 
#
# Import packages that we will need.
from pathlib import Path
import yaml
import pyjokes
import sys
sys.path.append(str(Path().absolute().parent.parent.parent))

from diffpy.srfit.fitbase import FitResults
from diffpy.structure.parsers import getParser
from scipy.optimize import least_squares
from cmi_demos.utils.helpers import makerecipe
from cmi_demos.utils.helpers import plotresults
print(pyjokes.get_joke())
# Out:
# The C language combines all the power of assembly language with all the ease-of-use of assembly language.

# %%
############### Config ##############################
# Give a file path to where your pdf (.gr) and (.cif) files are located.
DPATH = Path("data")

# Give an identifying name for the refinement, similar
# to what you would name a fit tree in PDFGui.
FIT_ID = "Fit_Pt_NP"

# Specify the names of the input PDF and cif files.
GR_NAME = "Pt-nanoparticles.gr"
CIF_NAME = "Pt.cif"

print(pyjokes.get_joke())
# Out:
# In C we had to code our own bugs. In C++ we can inherit them.

# %%
######## Experimental PDF Config ######################
# Specify the min, max, and step r-values of the PDF (that we want to fit over)
# also, specify the Q_max and Q_min values used to reduce the PDF.
PDF_RMIN = 1.5
PDF_RMAX = 50
PDF_RSTEP = 0.01
QMAX = 25
QMIN = 0.1

########PDF initialize refinable variables #############
# We explicitly specify the lattice parameters, scale,
# isotropic thermal parameters, and a correlated motion parameter.
CUBICLAT_I = 3.9
SCALE_I = 0.6
UISO_I = 0.01
DELTA2_I = 4

# For the NP case, we also provide an initial guess
# for the average crystallite size, in Angstroms.
PSIZE_I = 40

print(pyjokes.get_joke())
# Out:
# There are 10 types of people: those who understand binary, those who don't, and those who were expecting this joke to be in trinary.

# %%
# First, let's read the fit results from the Ni fit.
# We parse out the refined values of Q_damp and Q_broad,
# instrumental parameters which will be fixed in this fit.

# We specify where to look for the fit results files, as well as
# a name of the file.
STANDARD_DIR = Path().absolute().parent / "example_1"
NIBASENAME = "Fit_Ni_Bulk"

STANDARD_RES_FILE = (STANDARD_DIR / (NIBASENAME + ".yml"))

print(pyjokes.get_joke())
# Out:
# What do you call a programmer from Finland? Nerdic.

# %%
# First, check of the file even exists
if STANDARD_RES_FILE.exists():

    # If it exists, let's open it and load the dictionary
    with open(STANDARD_RES_FILE, 'r') as infile:
        refined_dict = yaml.safe_load(infile)

    # If we find either of these strings in the dictionary, we load it
    if "Calib_Qbroad" in refined_dict:
        # ... we grab the value.
        QBROAD_I = refined_dict["Calib_Qbroad"]["value"]

    if "Calib_Qdamp" in refined_dict:
        # ... we grab the value.
        QDAMP_I = refined_dict["Calib_Qdamp"]["value"]

    # If we don't find these strings, something is wrong...            
    if "Calib_Qbroad" not in refined_dict or "Calib_Qdamp" not in refined_dict:
        
        # ... so we print a warning to the terminal...
        print(f"\nWe did not find instrumental parameters in"
              f"{STANDARD_RES_FILE}. Please make sure tutorial 1 has been")

        # ...and we exit the script with code "1," meaning abnormal termination
        sys.exit(1)
        
# If the fit result file does not exist, something is wrong.
else:

    # We print a warning to the terminal...
    print("\nTutorial 1, which refines instrumental parameters, "
          "does not appear to have been run.\nThese instrumental "
          "parameters are necessary to run this tutorial.\n"
          "Please run tutorial 1 first")

    # ...and we exit the script with code "1," meaning abnormal termination
    sys.exit(1)

print(pyjokes.get_joke())
# Out:
# If you play a Windows CD backwards, you'll hear satanic chanting ... worse still, if you play it forwards, it installs Windows.

# %%
# Make some folders to store our output files.
resdir = Path("res")
fitdir = Path("fit")
figdir = Path("fig")

folders = [resdir, fitdir, figdir]

# Loop over all folders
for folder in folders:

    # If the folder does not exist...
    if not folder.exists():

        # ...then we create it.
        folder.mkdir()

# Let the user know what fit we are running by printing to terminal.
basename = FIT_ID
print(basename)

# Establish the full location of the data.
data = DPATH / GR_NAME

# Establish the location of the cif file with the structure of interest
# and load it into a diffpy structure object.
strudir = DPATH
cif_file = strudir / CIF_NAME

print(pyjokes.get_joke())
# Out:
# Fit_Pt_NP

# %%
p_cif = getParser('cif')
structure = p_cif.parseFile(str(cif_file))
space_group = p_cif.spacegroup.short_name
print(pyjokes.get_joke())
# Out:
# Triumphantly, Beth removed Python 2.7 from her server in 2030. 'Finally!' she said with glee, only to see the announcement for Python 4.4.

# %%
# Initialize the Fit Recipe by giving it this diffpy structure
# as well as the path to the data file.
recipe = makerecipe(cif_file, data)
print(pyjokes.get_joke())

# %%
recipe.crystal.profile.setCalculationRange(xmin=PDF_RMIN, xmax=PDF_RMAX, dx=PDF_RSTEP)

# Add, initialize, and tag variables in the Fit Recipe object.
# In this case we also add psize, which is the NP size.
recipe.addVar(recipe.crystal.s1, SCALE_I, tag="scale")


# Set an equation, based on your PDF generators. Here we add an extra layer
# of complexity, incorporating "f" int our equation. This new term
# incorporates damping to our PDF to model the effect of finite crystallite size.
# In this case we use a function which models a spherical NP.
from diffpy.srfit.pdf.characteristicfunctions import sphericalCF
recipe.crystal.registerFunction(sphericalCF, name="f")
recipe.crystal.setEquation("s1*G1*f")

recipe.addVar(recipe.crystal.psize, PSIZE_I, tag="psize")


# Use the srfit function constrainAsSpaceGroup to constrain
# the lattice and ADP parameters according to the Fm-3m space group.
from diffpy.srfit.structure import constrainAsSpaceGroup
spacegroupparams = constrainAsSpaceGroup(recipe.crystal.G1.phase,
                                         space_group)

# Initialize the instrument parameters, Q_damp and Q_broad, and
# assign Q_max and Q_min.
recipe.crystal.G1.qdamp.value = QDAMP_I
recipe.crystal.G1.qbroad.value = QBROAD_I
recipe.crystal.G1.setQmax(QMAX)
recipe.crystal.G1.setQmin(QMIN)
print(pyjokes.get_joke())

# %%
for par in spacegroupparams.latpars:
    recipe.addVar(par,
                  value=CUBICLAT_I,
                  fixed=False,
                  name="fcc_Lat",
                  tag="lat")

for par in spacegroupparams.adppars:
    recipe.addVar(par,
                  value=UISO_I,
                  fixed=False,
                  name="fcc_ADP",
                  tag="adp")

# Add delta, but not instrumental parameters to Fit Recipe.
# The instrumental parameters will remain fixed at values obtained from
# the Ni calibrant in our previous example. As we have not added them through
# recipe.addVar, they cannot be refined.
recipe.addVar(recipe.crystal.G1.delta2,
              name="Pt_Delta2",
              value=DELTA2_I,
              tag="d2")
print(pyjokes.get_joke())

# %%
print(recipe.show())
recipe.residual()
plotresults(recipe,"test")
print(pyjokes.get_joke())
# Out:
# Parameters
# ------------------------------------------------------------------------------
# s1          0.6
# psize       40
# fcc_Lat     3.9
# fcc_ADP     0.01
# Pt_Delta2   4.0
#
# crystal.s1      0.6
# crystal.r       [ 1.5   1.51  1.52 ... 49.98 49.99 50.  ]
# crystal.y       [-0.627457  -0.620057  -0.610519  ...  0.0108869  0.0105427  0
# crystal.dy      [1. 1. 1. ... 1. 1. 1.]
# crystal.psize   40
#
# crystal.G1.delta1   0.0
# crystal.G1.delta2   4.0
# crystal.G1.qbroad   0.016808592920450435
# crystal.G1.scale    1.0
# crystal.G1.qdamp    0.04529773609487335
#
# crystal.G1.phase.lattice.a      3.9
# crystal.G1.phase.lattice.b      3.9237
# crystal.G1.phase.lattice.c      3.9237
# crystal.G1.phase.lattice.alpha  90.0
# crystal.G1.phase.lattice.beta   90.0
# crystal.G1.phase.lattice.gamma  90.0
#
# crystal.G1.phase.Pt0.x          0.0
# crystal.G1.phase.Pt0.y          0.0
# crystal.G1.phase.Pt0.z          0.0
# crystal.G1.phase.Pt0.occupancy  1.0
# crystal.G1.phase.Pt0.occ        1.0
# crystal.G1.phase.Pt0.U11        0.01
# crystal.G1.phase.Pt0.U22        0.01
# crystal.G1.phase.Pt0.U33        0.01
# crystal.G1.phase.Pt0.U12        0.0
# crystal.G1.phase.Pt0.U21        0.0
# crystal.G1.phase.Pt0.U13        0.0
# crystal.G1.phase.Pt0.U31        0.0
# crystal.G1.phase.Pt0.U23        0.0
# crystal.G1.phase.Pt0.U32        0.0
# crystal.G1.phase.Pt0.Uiso       0.01
# crystal.G1.phase.Pt0.B11        0.7895683520871487
# crystal.G1.phase.Pt0.B22        0.7895683520871487
# crystal.G1.phase.Pt0.B33        0.7895683520871487
# crystal.G1.phase.Pt0.B12        0.0
# crystal.G1.phase.Pt0.B21        0.0
# crystal.G1.phase.Pt0.B13        0.0
# crystal.G1.phase.Pt0.B31        0.0
# crystal.G1.phase.Pt0.B23        0.0
# crystal.G1.phase.Pt0.B32        0.0
# crystal.G1.phase.Pt0.Biso       0.7895683520871487
#
# crystal.G1.phase.Pt1.x          0.0
# crystal.G1.phase.Pt1.y          0.5
# crystal.G1.phase.Pt1.z          0.5
# crystal.G1.phase.Pt1.occupancy  1.0
# crystal.G1.phase.Pt1.occ        1.0
# crystal.G1.phase.Pt1.U11        0.1
# crystal.G1.phase.Pt1.U22        0.1
# crystal.G1.phase.Pt1.U33        0.1
# crystal.G1.phase.Pt1.U12        0.0
# crystal.G1.phase.Pt1.U21        0.0
# crystal.G1.phase.Pt1.U13        0.0
# crystal.G1.phase.Pt1.U31        0.0
# crystal.G1.phase.Pt1.U23        0.0
# crystal.G1.phase.Pt1.U32        0.0
# crystal.G1.phase.Pt1.Uiso       0.1
# crystal.G1.phase.Pt1.B11        7.895683520871486
# crystal.G1.phase.Pt1.B22        7.895683520871486
# crystal.G1.phase.Pt1.B33        7.895683520871486
# crystal.G1.phase.Pt1.B12        0.0
# crystal.G1.phase.Pt1.B21        0.0
# crystal.G1.phase.Pt1.B13        0.0
# crystal.G1.phase.Pt1.B31        0.0
# crystal.G1.phase.Pt1.B23        0.0
# crystal.G1.phase.Pt1.B32        0.0
# crystal.G1.phase.Pt1.Biso       7.895683520871486
#
# crystal.G1.phase.Pt2.x          0.5
# crystal.G1.phase.Pt2.y          0.5
# crystal.G1.phase.Pt2.z          0.0
# crystal.G1.phase.Pt2.occupancy  1.0
# crystal.G1.phase.Pt2.occ        1.0
# crystal.G1.phase.Pt2.U11        0.1
# crystal.G1.phase.Pt2.U22        0.1
# crystal.G1.phase.Pt2.U33        0.1
# crystal.G1.phase.Pt2.U12        0.0
# crystal.G1.phase.Pt2.U21        0.0
# crystal.G1.phase.Pt2.U13        0.0
# crystal.G1.phase.Pt2.U31        0.0
# crystal.G1.phase.Pt2.U23        0.0
# crystal.G1.phase.Pt2.U32        0.0
# crystal.G1.phase.Pt2.Uiso       0.1
# crystal.G1.phase.Pt2.B11        7.895683520871486
# crystal.G1.phase.Pt2.B22        7.895683520871486
# crystal.G1.phase.Pt2.B33        7.895683520871486
# crystal.G1.phase.Pt2.B12        0.0
# crystal.G1.phase.Pt2.B21        0.0
# crystal.G1.phase.Pt2.B13        0.0
# crystal.G1.phase.Pt2.B31        0.0
# crystal.G1.phase.Pt2.B23        0.0
# crystal.G1.phase.Pt2.B32        0.0
# crystal.G1.phase.Pt2.Biso       7.895683520871486
#
# crystal.G1.phase.Pt3.x          0.5
# crystal.G1.phase.Pt3.y          0.0
# crystal.G1.phase.Pt3.z          0.5
# crystal.G1.phase.Pt3.occupancy  1.0
# crystal.G1.phase.Pt3.occ        1.0
# crystal.G1.phase.Pt3.U11        0.1
# crystal.G1.phase.Pt3.U22        0.1
# crystal.G1.phase.Pt3.U33        0.1
# crystal.G1.phase.Pt3.U12        0.0
# crystal.G1.phase.Pt3.U21        0.0
# crystal.G1.phase.Pt3.U13        0.0
# crystal.G1.phase.Pt3.U31        0.0
# crystal.G1.phase.Pt3.U23        0.0
# crystal.G1.phase.Pt3.U32        0.0
# crystal.G1.phase.Pt3.Uiso       0.1
# crystal.G1.phase.Pt3.B11        7.895683520871486
# crystal.G1.phase.Pt3.B22        7.895683520871486
# crystal.G1.phase.Pt3.B33        7.895683520871486
# crystal.G1.phase.Pt3.B12        0.0
# crystal.G1.phase.Pt3.B21        0.0
# crystal.G1.phase.Pt3.B13        0.0
# crystal.G1.phase.Pt3.B31        0.0
# crystal.G1.phase.Pt3.B23        0.0
# crystal.G1.phase.Pt3.B32        0.0
# crystal.G1.phase.Pt3.Biso       7.895683520871486
#
# Constraints
# ------------------------------------------------------------------------------
# crystal.G1.phase.Pt1.Uiso <-- Uiso_0
# crystal.G1.phase.Pt2.Uiso <-- Uiso_0
# crystal.G1.phase.Pt3.Uiso <-- Uiso_0
# crystal.G1.phase.lattice.b <-- a
# crystal.G1.phase.lattice.c <-- a
# None
# 1
# There are 10 types of people: those who understand binary, those who don't, and those who were expecting this joke to be in trinary.

# %%
# Tell the Fit Recipe we want to write the maximum amount of
# information to the terminal during fitting.
recipe.fithooks[0].verbose = 3

refine_params = ["scale", "lat", "psize", "adp", "d2", "all"]

recipe.fix("all")

for params in refine_params:
    recipe.free(params)
    print(f"\n****\nFitting {recipe.getNames()} against "
          f"{GR_NAME} with {CIF_NAME}\n")
    
    plotresults(recipe,"test")
    input("\nPress enter to continue...")
    least_squares(recipe.residual, recipe.values, x_scale="jac")
# Out:
# ****
# Fitting ['s1'] against Pt-nanoparticles.gr with Pt.cif
# Press enter to continue...
# 131
# Residual: 48.44759553497146
# Variables
#   s1 = 0.585669
# 132
# Residual: 48.44759553497434
# Variables
#   s1 = 0.585669
# 133
# Residual: 48.44759553497146
# Variables
#   s1 = 0.585669
#
# ****
# Fitting ['s1', 'fcc_Lat'] against Pt-nanoparticles.gr with Pt.cif
# Press enter to continue...
# 134
# Residual: 48.44759553497146
# Variables
#   fcc_Lat = 3.924856
#   s1 = 0.585669
# 135
# Residual: 48.447595534974226
# Variables
#   fcc_Lat = 3.924856
#   s1 = 0.585669
# 136
# Residual: 48.44759553907791
# Variables
#   fcc_Lat = 3.924856
#   s1 = 0.585669
# 137
# Residual: 48.44759553497098
# Variables
#   fcc_Lat = 3.924856
#   s1 = 0.585669
# 138
# Residual: 48.44759553497375
# Variables
#   fcc_Lat = 3.924856
#   s1 = 0.585669
# 139
# Residual: 48.44759553908051
# Variables
#   fcc_Lat = 3.924856
#   s1 = 0.585669
#
# ****
# Fitting ['s1', 'psize', 'fcc_Lat'] against Pt-nanoparticles.gr with Pt.cif
# Press enter to continue...
# 140
# Residual: 48.44759553908051
# Variables
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669
# 141
# Residual: 48.4475955390789
# Variables
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669
# 142
# Residual: 48.44759553907943
# Variables
#   fcc_Lat = 3.924856
#   psize = 37.434959
#   s1 = 0.585669
# 143
# Residual: 48.44759555126057
# Variables
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669
# 144
# Residual: 48.44759553497507
# Variables
#   fcc_Lat = 3.924856
#   psize = 37.434959
#   s1 = 0.585669
# 145
# Residual: 48.447595534977836
# Variables
#   fcc_Lat = 3.924856
#   psize = 37.434959
#   s1 = 0.585669
# 146
# Residual: 48.447595534976166
# Variables
#   fcc_Lat = 3.924856
#   psize = 37.434960
#   s1 = 0.585669
# 147
# Residual: 48.44759553922615
# Variables
#   fcc_Lat = 3.924856
#   psize = 37.434959
#   s1 = 0.585669
#
# ****
# Fitting ['s1', 'psize', 'fcc_Lat', 'fcc_ADP'] against Pt-nanoparticles.gr with Pt.cif
# Press enter to continue...
# 148
# Residual: 48.44759553922615
# Variables
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434959
#   s1 = 0.585669
# 149
# Residual: 48.447595539224544
# Variables
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434959
#   s1 = 0.585669
# 150
# Residual: 48.44759553922562
# Variables
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434960
#   s1 = 0.585669
# 151
# Residual: 48.44759555154925
# Variables
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434959
#   s1 = 0.585669
# 152
# Residual: 48.447595544411094
# Variables
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434959
#   s1 = 0.585669
# 153
# Residual: 48.44759553497453
# Variables
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434959
#   s1 = 0.585669
# 154
# Residual: 48.4475955349773
# Variables
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434959
#   s1 = 0.585669
# 155
# Residual: 48.44759553497571
# Variables
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434960
#   s1 = 0.585669
# 156
# Residual: 48.447595539229376
# Variables
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434959
#   s1 = 0.585669
# 157
# Residual: 48.447595540115024
# Variables
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434959
#   s1 = 0.585669
#
# ****
# Fitting ['s1', 'psize', 'fcc_Lat', 'fcc_ADP', 'Pt_Delta2'] against Pt-nanoparticles.gr with Pt.cif
# Press enter to continue...
# 158
# Residual: 48.447595540115024
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434959
#   s1 = 0.585669
# 159
# Residual: 48.44759553994453
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434959
#   s1 = 0.585669
# 160
# Residual: 48.44759554006401
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434960
#   s1 = 0.585669
# 161
# Residual: 48.44759554441078
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434959
#   s1 = 0.585669
# 162
# Residual: 48.4475955552469
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434959
#   s1 = 0.585669
# 163
# Residual: 48.447595540098256
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434959
#   s1 = 0.585669
# 164
# Residual: 48.44759553499461
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434960
#   s1 = 0.585669
# 165
# Residual: 48.447595534997355
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434960
#   s1 = 0.585669
# 166
# Residual: 48.447595534995266
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434961
#   s1 = 0.585669
# 167
# Residual: 48.447595539112
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434960
#   s1 = 0.585669
# 168
# Residual: 48.44759554039203
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434960
#   s1 = 0.585669
# 169
# Residual: 48.44759553499484
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434960
#   s1 = 0.585669
#
# ****
# Fitting ['s1', 'psize', 'fcc_Lat', 'fcc_ADP', 'Pt_Delta2'] against Pt-nanoparticles.gr with Pt.cif
# Press enter to continue...
# 170
# Residual: 48.44759553499484
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434960
#   s1 = 0.585669
# 171
# Residual: 48.44759553499793
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434960
#   s1 = 0.585669
# 172
# Residual: 48.447595534995536
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434961
#   s1 = 0.585669
# 173
# Residual: 48.44759553911267
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434960
#   s1 = 0.585669
# 174
# Residual: 48.44759554037591
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434960
#   s1 = 0.585669
# 175
# Residual: 48.447595534995294
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434960
#   s1 = 0.585669
# 176
# Residual: 48.447595534970894
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669
# 177
# Residual: 48.44759553497364
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669
# 178
# Residual: 48.44759553497149
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434959
#   s1 = 0.585669
# 179
# Residual: 48.44759553907728
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669
# 180
# Residual: 48.44759554013206
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669
# 181
# Residual: 48.447595534970844
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669

# %%
# We use the savetxt method of the profile to write a text file
# containing the measured and fitted PDF to disk.
# The file is named based on the basename we created earlier, and
# written to the fitdir directory.
profile = recipe.crystal.profile
profile.savetxt(fitdir / (basename + ".fit"))

# We use the FitResults function to parse out the results from
# the optimized Fit Recipe.
res = FitResults(recipe)

# We print these results to the terminal.
res.printResults()

print(pyjokes.get_joke())
# Out:
# 120
# Residual: 48.447595534972
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669
# 121
# Residual: 48.44759553497176
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669
# 122
# Residual: 48.447595534971775
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669
# 123
# Residual: 48.447595534971455
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669
# 124
# Residual: 48.447595536836474
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669
# 125
# Residual: 48.44759553674112
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669
# 126
# Residual: 48.44759553497237
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669
# 127
# Residual: 48.44759553497069
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669
# 128
# Residual: 48.44759553497137
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669
# 129
# Residual: 48.44759553497146
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669
# 130
# Residual: 48.44759553497146
# Variables
#   Pt_Delta2 = 3.548545
#   fcc_ADP = 0.008931
#   fcc_Lat = 3.924856
#   psize = 37.434958
#   s1 = 0.585669
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       48.44759553
# Contributions  48.44759553
# Restraints     0.00000000
# Chi2           48.44759553
# Reduced Chi2   0.00999744
# Rw             0.10594588
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Pt_Delta2  3.54854475e+00 +/- 3.23668009e-01
# fcc_ADP    8.93111043e-03 +/- 3.33684421e-04
# fcc_Lat    3.92485623e+00 +/- 9.12716661e-04
# psize      3.74349581e+01 +/- 1.35545754e+00
# s1         5.85668517e-01 +/- 1.58074532e-02
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(s1, psize)            -0.5531
# corr(fcc_ADP, Pt_Delta2)   0.3994
# corr(psize, Pt_Delta2)     0.3674
# corr(s1, fcc_ADP)          0.3635
# corr(s1, Pt_Delta2)        -0.3017
# corr(psize, fcc_ADP)       0.2669
# Optimist: The glass is half full. Pessimist: The glass is half empty. Programmer: The glass is twice as large as necessary.

# %%
# We grab the fit Rw
rw = res.rw

# We use the saveResults method of FitResults to write a text file
# containing the fitted parameters and fit quality indices to disk.
# The file is named based on the basename we created earlier, and
# written to the resdir directory.
header = "crystal_HF.\n"
res.saveResults(resdir / (basename + ".res"), header=header)

# We use the plotresults function we created earlier to make a plot of
# the measured, calculated, and difference curves. We show this
# as an interactive window and then write a pdf file to disk.
# The file is named based on the basename we created earlier, and
# written to the figdir directory.
plotresults(recipe, figdir / basename)
# plt.ion()

print(pyjokes.get_joke())
# Out:
# QA Engineer walks into a bar. Orders a beer. Orders 0 beers. Orders 999999999 beers. Orders a lizard. Orders -1 beers. Orders a sfdeljknesv.

# %%
# Let make a dictionary to hold our results. This way make reloading the
# fit parameters easier later
refined_dict = dict()

refined_dict['rw'] = rw.item()

recipe.free("all")
# We loop over the variable names, the variable values, and the variable uncertainties (esd)
for name, val, unc in zip(res.varnames, res.varvals, res.varunc):
    # We store the refined value for this variable using the "value" key.
    # We use the ".item()" method because "res.varvals" exist as
    # numpy.float64 objects, and we want them as regular python floats.
    if name not in refined_dict:
        refined_dict[name] = dict()
    refined_dict[name]["value"] = val.item()
    refined_dict[name]["uncert"] = unc.item()

with open(basename + ".yml", 'w') as outfile:
    yaml.safe_dump(refined_dict, outfile)

print(pyjokes.get_joke())
# Out:
# If you put a million monkeys at a million keyboards, one of them will eventually write a Java program. The rest of them will write Perl.
