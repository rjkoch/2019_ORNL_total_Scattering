# %%
#!/usr/bin/env python
###################################
#                                 #
# File coded by: Robert J. Koch   #
#                                 #
###################################
#
# Example 1, Refining PDF from Ni to characterize instrument
#
# This Diffpy-CMI notebook will carry out a structural refinement of a measured
# PDF from nickel.  Nickel is a standard, and allows us to understand how the
# instrument affects our data, so that we can correct for it when we
# look at an unknown sample (in example 2).
#
# Import packages that we will need.
from pathlib import Path
import yaml
import pyjokes
import sys
sys.path.append(str(Path().absolute().parent.parent.parent))

from diffpy.srfit.fitbase import FitResults
from diffpy.structure.parsers import getParser
from scipy.optimize import least_squares
from cmi_demos.utils.helpers import makerecipe
from cmi_demos.utils.helpers import plotresults
print(pyjokes.get_joke())
# Out:
# There are 10 types of people: those who understand binary, those who don't, and those who were expecting this joke to be in trinary.

# %%
############### Config ##############################
# Give a file path to where your pdf (.gr) and (.cif) files are located.
# In this case it is in a folder called "data," in the same directory as
# this script.
DPATH = Path("data")

# Give an identifying name for the refinement, similar
# to what you would name a fit tree in PDFGui.
FIT_ID = "Fit_Ni_Bulk"

# Specify the names of the input PDF and cif files.
GR_NAME = "Ni.gr"
CIF_NAME = "Ni.cif"
print(pyjokes.get_joke())
# Out:
# What do you mean 911 is only for emergencies? I've got a merge conflict.

# %%
######## Experimental PDF Config ######################
# Specify the min, max, and step r-values of the PDF (that we want to fit over)
# also, specify the Q_max and Q_min values used to reduce the PDF.
PDF_RMIN = 1.5
PDF_RMAX = 50
PDF_RSTEP = 0.01
QMAX = 25
QMIN = 0.1

######## PDF Initialize refinable variables #############
# We explicitly specify the initial values for the lattice
# parameter, scale, and isotropic thermal parameters, as well
# as a correlated motion parameter, in this case delta_2.
CUBICLAT_I = 3.52
SCALE_I = 0.4
UISO_I = 0.005
DELTA2_I = 2

# We give initial values for the instrumental parameters, but because
# this is a calibrant, we will also refine these values.
QDAMP_I = 0.04
QBROAD_I = 0.02


print(pyjokes.get_joke())
# Out:
# Ubuntu users are apt to get this joke.

# %%
# Make some folders to store our output files.
resdir = Path("res")
fitdir = Path("fit")
figdir = Path("fig")

folders = [resdir, fitdir, figdir]

# Loop over all folders
for folder in folders:

    # If the folder does not exist...
    if not folder.exists():

        # ...then we create it.
        folder.mkdir()


# Let the user know what fit we are running by printing to terminal.
basename = FIT_ID
print(basename)

# Establish the full location of the data.
data = DPATH / GR_NAME

# Establish the location of the cif file with the structure of interest
# and load it into a diffpy structure object.
strudir = DPATH
cif_file = strudir / CIF_NAME

print(pyjokes.get_joke())
# Out:
# Fit_Ni_Bulk
# Unix is user friendly. It's just very particular about who its friends are.

# %%
p_cif = getParser('cif')
structure = p_cif.parseFile(str(cif_file))
space_group = p_cif.spacegroup.short_name
print(pyjokes.get_joke())
# Out:
# How do you know whether a person is a Vim user? Don't worry, they'll tell you.

# %%
print(structure)
print(pyjokes.get_joke())
# Out:
# lattice=Lattice(a=3.52, b=3.52, c=3.52, alpha=90, beta=90, gamma=90)
# Ni   0.000000 0.000000 0.000000 1.0000
# Ni   0.000000 0.500000 0.500000 1.0000
# Ni   0.500000 0.500000 0.000000 1.0000
# Ni   0.500000 0.000000 0.500000 1.0000
# What does 'Emacs' stand for? 'Exclusively used by middle aged computer scientists.'

# %%
# Initialize the Fit Recipe by giving it this diffpy structure
# as well as the path to the data file.
recipe = makerecipe(cif_file, data)
recipe.addVar(recipe.crystal.s1, SCALE_I, tag="scale")
print(recipe.show())
print(pyjokes.get_joke())
# Out:
# Parameters
# ------------------------------------------------------------------------------
# s1  0.4
#
# crystal.s1  0.4
# crystal.r   [0.000e+00 1.000e-02 2.000e-02 ... 5.998e+01 5.999e+01 6.000e+01]
# crystal.y   [ 0.         -0.00049796 -0.00096337 ...  0.0325963   0.0272721
#
# crystal.dy  [1. 1. 1. ... 1. 1. 1.]
#
# crystal.G1.delta1   0.0
# crystal.G1.delta2   0.0
# crystal.G1.qbroad   0.0
# crystal.G1.scale    1.0
# crystal.G1.qdamp    0.0
#
# crystal.G1.phase.lattice.a      3.52
# crystal.G1.phase.lattice.b      3.52
# crystal.G1.phase.lattice.c      3.52
# crystal.G1.phase.lattice.alpha  90.0
# crystal.G1.phase.lattice.beta   90.0
# crystal.G1.phase.lattice.gamma  90.0
#
# crystal.G1.phase.Ni0.x          0.0
# crystal.G1.phase.Ni0.y          0.0
# crystal.G1.phase.Ni0.z          0.0
# crystal.G1.phase.Ni0.occupancy  1.0
# crystal.G1.phase.Ni0.occ        1.0
# crystal.G1.phase.Ni0.U11        0.0012665147955292222
# crystal.G1.phase.Ni0.U22        0.0012665147955292222
# crystal.G1.phase.Ni0.U33        0.0012665147955292222
# crystal.G1.phase.Ni0.U12        0.0
# crystal.G1.phase.Ni0.U21        0.0
# crystal.G1.phase.Ni0.U13        0.0
# crystal.G1.phase.Ni0.U31        0.0
# crystal.G1.phase.Ni0.U23        0.0
# crystal.G1.phase.Ni0.U32        0.0
# crystal.G1.phase.Ni0.Uiso       0.0012665147955292222
# crystal.G1.phase.Ni0.B11        0.09999999999999999
# crystal.G1.phase.Ni0.B22        0.09999999999999999
# crystal.G1.phase.Ni0.B33        0.09999999999999999
# crystal.G1.phase.Ni0.B12        0.0
# crystal.G1.phase.Ni0.B21        0.0
# crystal.G1.phase.Ni0.B13        0.0
# crystal.G1.phase.Ni0.B31        0.0
# crystal.G1.phase.Ni0.B23        0.0
# crystal.G1.phase.Ni0.B32        0.0
# crystal.G1.phase.Ni0.Biso       0.09999999999999999
#
# crystal.G1.phase.Ni1.x          0.0
# crystal.G1.phase.Ni1.y          0.5
# crystal.G1.phase.Ni1.z          0.5
# crystal.G1.phase.Ni1.occupancy  1.0
# crystal.G1.phase.Ni1.occ        1.0
# crystal.G1.phase.Ni1.U11        0.0012665147955292222
# crystal.G1.phase.Ni1.U22        0.0012665147955292222
# crystal.G1.phase.Ni1.U33        0.0012665147955292222
# crystal.G1.phase.Ni1.U12        0.0
# crystal.G1.phase.Ni1.U21        0.0
# crystal.G1.phase.Ni1.U13        0.0
# crystal.G1.phase.Ni1.U31        0.0
# crystal.G1.phase.Ni1.U23        0.0
# crystal.G1.phase.Ni1.U32        0.0
# crystal.G1.phase.Ni1.Uiso       0.0012665147955292222
# crystal.G1.phase.Ni1.B11        0.09999999999999999
# crystal.G1.phase.Ni1.B22        0.09999999999999999
# crystal.G1.phase.Ni1.B33        0.09999999999999999
# crystal.G1.phase.Ni1.B12        0.0
# crystal.G1.phase.Ni1.B21        0.0
# crystal.G1.phase.Ni1.B13        0.0
# crystal.G1.phase.Ni1.B31        0.0
# crystal.G1.phase.Ni1.B23        0.0
# crystal.G1.phase.Ni1.B32        0.0
# crystal.G1.phase.Ni1.Biso       0.09999999999999999
#
# crystal.G1.phase.Ni2.x          0.5
# crystal.G1.phase.Ni2.y          0.5
# crystal.G1.phase.Ni2.z          0.0
# crystal.G1.phase.Ni2.occupancy  1.0
# crystal.G1.phase.Ni2.occ        1.0
# crystal.G1.phase.Ni2.U11        0.0012665147955292222
# crystal.G1.phase.Ni2.U22        0.0012665147955292222
# crystal.G1.phase.Ni2.U33        0.0012665147955292222
# crystal.G1.phase.Ni2.U12        0.0
# crystal.G1.phase.Ni2.U21        0.0
# crystal.G1.phase.Ni2.U13        0.0
# crystal.G1.phase.Ni2.U31        0.0
# crystal.G1.phase.Ni2.U23        0.0
# crystal.G1.phase.Ni2.U32        0.0
# crystal.G1.phase.Ni2.Uiso       0.0012665147955292222
# crystal.G1.phase.Ni2.B11        0.09999999999999999
# crystal.G1.phase.Ni2.B22        0.09999999999999999
# crystal.G1.phase.Ni2.B33        0.09999999999999999
# crystal.G1.phase.Ni2.B12        0.0
# crystal.G1.phase.Ni2.B21        0.0
# crystal.G1.phase.Ni2.B13        0.0
# crystal.G1.phase.Ni2.B31        0.0
# crystal.G1.phase.Ni2.B23        0.0
# crystal.G1.phase.Ni2.B32        0.0
# crystal.G1.phase.Ni2.Biso       0.09999999999999999
#
# crystal.G1.phase.Ni3.x          0.5
# crystal.G1.phase.Ni3.y          0.0
# crystal.G1.phase.Ni3.z          0.5
# crystal.G1.phase.Ni3.occupancy  1.0
# crystal.G1.phase.Ni3.occ        1.0
# crystal.G1.phase.Ni3.U11        0.0012665147955292222
# crystal.G1.phase.Ni3.U22        0.0012665147955292222
# crystal.G1.phase.Ni3.U33        0.0012665147955292222
# crystal.G1.phase.Ni3.U12        0.0
# crystal.G1.phase.Ni3.U21        0.0
# crystal.G1.phase.Ni3.U13        0.0
# crystal.G1.phase.Ni3.U31        0.0
# crystal.G1.phase.Ni3.U23        0.0
# crystal.G1.phase.Ni3.U32        0.0
# crystal.G1.phase.Ni3.Uiso       0.0012665147955292222
# crystal.G1.phase.Ni3.B11        0.09999999999999999
# crystal.G1.phase.Ni3.B22        0.09999999999999999
# crystal.G1.phase.Ni3.B33        0.09999999999999999
# crystal.G1.phase.Ni3.B12        0.0
# crystal.G1.phase.Ni3.B21        0.0
# crystal.G1.phase.Ni3.B13        0.0
# crystal.G1.phase.Ni3.B31        0.0
# crystal.G1.phase.Ni3.B23        0.0
# crystal.G1.phase.Ni3.B32        0.0
# crystal.G1.phase.Ni3.Biso       0.09999999999999999
# None
# Number of days since I have encountered an off-by-one error: 0.

# %%
# Let's set the calculation range!
recipe.crystal.profile.setCalculationRange(xmin=PDF_RMIN, xmax=PDF_RMAX, dx=PDF_RSTEP)


# Initialize the instrument parameters, Q_damp and Q_broad, and
# assign Q_max and Q_min, all part of the PDF Generator object.
# It's possible that the PDFParse function we used above
# already parsed out ths information, but in case it didn't, we set it
# explicitly again here.
# All parameter objects can have their value assigned using the
# below ".value = " syntax.
recipe.crystal.G1.qdamp.value = QDAMP_I
recipe.crystal.G1.qbroad.value = QBROAD_I
recipe.crystal.G1.setQmax(QMAX)
recipe.crystal.G1.setQmin(QMIN)



print(pyjokes.get_joke())
# Out:
# Software developers like to solve problems. If there are no problems handily available, they will create their own.

# %%
# Add delta and instrumental parameters to Fit Recipe.
# These parameters are contained as part of the PDF Generator object
# and initialized with values as defined in the opening of the script.
# We give them unique names, and tag them with our choice of relevant strings.
recipe.addVar(recipe.crystal.G1.delta2,
              name="Ni_Delta2",
              value=DELTA2_I,
              tag="d2")

recipe.addVar(recipe.crystal.G1.qdamp,
              fixed=False,
              name="Calib_Qdamp",
              tag="inst")

recipe.addVar(recipe.crystal.G1.qbroad,
              fixed=False,
              name="Calib_Qbroad",
              tag="inst")


# Configure some additional fit variables pertaining to symmetry.
# We can use the srfit function constrainAsSpaceGroup to constrain
# the lattice and ADP parameters according to the Fm-3m space group.
# First we establish the relevant parameters, then we cycle through
# the parameters and activate and tag them.
# We must explicitly set the ADP parameters, because in this case, the
# CIF had no ADP data.
from diffpy.srfit.structure import constrainAsSpaceGroup

# Create the symmetry distinct parameter sets, and constrain them
# in the generator.
spacegroupparams = constrainAsSpaceGroup(recipe.crystal.G1.phase,
                                         space_group)

# Loop over all the symmetry distinct lattice parameters and add
# them to the recipe.
# We give them unique names, and tag them with our choice of a relevant string.
for par in spacegroupparams.latpars:
    recipe.addVar(par,
                  value=CUBICLAT_I,
                  fixed=False,
                  name="fcc_Lat",
                  tag="lat")

# Loop over all the symmetry distinct ADPs and add
# them to the recipe.
# We give them unique names, and tag them with our choice of a relevant string.
for par in spacegroupparams.adppars:
    recipe.addVar(par,
                  value=UISO_I,
                  fixed=False,
                  name="fcc_ADP",
                  tag="adp")
print(pyjokes.get_joke())
# Out:
# There are II types of people: Those who understand Roman Numerals and those who don't.

# %%
print(recipe.show())
recipe.residual()
plotresults(recipe,"test")
print(pyjokes.get_joke())
# Out:
# Parameters
# ------------------------------------------------------------------------------
# s1              0.4
# Ni_Delta2       2.0
# Calib_Qdamp     0.04
# Calib_Qbroad    0.02
# fcc_Lat         3.52
# fcc_ADP         0.005
#
# crystal.s1  0.4
# crystal.r   [ 1.5   1.51  1.52 ... 49.98 49.99 50.  ]
# crystal.y   [-0.708894  -0.701933  -0.69217   ...  0.0886073  0.1107     0.131
# crystal.dy  [1. 1. 1. ... 1. 1. 1.]
#
# crystal.G1.delta1   0.0
# crystal.G1.delta2   2.0
# crystal.G1.qbroad   0.02
# crystal.G1.scale    1.0
# crystal.G1.qdamp    0.04
#
# crystal.G1.phase.lattice.a      3.52
# crystal.G1.phase.lattice.b      3.52
# crystal.G1.phase.lattice.c      3.52
# crystal.G1.phase.lattice.alpha  90.0
# crystal.G1.phase.lattice.beta   90.0
# crystal.G1.phase.lattice.gamma  90.0
#
# crystal.G1.phase.Ni0.x          0.0
# crystal.G1.phase.Ni0.y          0.0
# crystal.G1.phase.Ni0.z          0.0
# crystal.G1.phase.Ni0.occupancy  1.0
# crystal.G1.phase.Ni0.occ        1.0
# crystal.G1.phase.Ni0.U11        0.005
# crystal.G1.phase.Ni0.U22        0.005
# crystal.G1.phase.Ni0.U33        0.005
# crystal.G1.phase.Ni0.U12        0.0
# crystal.G1.phase.Ni0.U21        0.0
# crystal.G1.phase.Ni0.U13        0.0
# crystal.G1.phase.Ni0.U31        0.0
# crystal.G1.phase.Ni0.U23        0.0
# crystal.G1.phase.Ni0.U32        0.0
# crystal.G1.phase.Ni0.Uiso       0.005
# crystal.G1.phase.Ni0.B11        0.39478417604357435
# crystal.G1.phase.Ni0.B22        0.39478417604357435
# crystal.G1.phase.Ni0.B33        0.39478417604357435
# crystal.G1.phase.Ni0.B12        0.0
# crystal.G1.phase.Ni0.B21        0.0
# crystal.G1.phase.Ni0.B13        0.0
# crystal.G1.phase.Ni0.B31        0.0
# crystal.G1.phase.Ni0.B23        0.0
# crystal.G1.phase.Ni0.B32        0.0
# crystal.G1.phase.Ni0.Biso       0.39478417604357435
#
# crystal.G1.phase.Ni1.x          0.0
# crystal.G1.phase.Ni1.y          0.5
# crystal.G1.phase.Ni1.z          0.5
# crystal.G1.phase.Ni1.occupancy  1.0
# crystal.G1.phase.Ni1.occ        1.0
# crystal.G1.phase.Ni1.U11        0.0012665147955292222
# crystal.G1.phase.Ni1.U22        0.0012665147955292222
# crystal.G1.phase.Ni1.U33        0.0012665147955292222
# crystal.G1.phase.Ni1.U12        0.0
# crystal.G1.phase.Ni1.U21        0.0
# crystal.G1.phase.Ni1.U13        0.0
# crystal.G1.phase.Ni1.U31        0.0
# crystal.G1.phase.Ni1.U23        0.0
# crystal.G1.phase.Ni1.U32        0.0
# crystal.G1.phase.Ni1.Uiso       0.0012665147955292222
# crystal.G1.phase.Ni1.B11        0.09999999999999999
# crystal.G1.phase.Ni1.B22        0.09999999999999999
# crystal.G1.phase.Ni1.B33        0.09999999999999999
# crystal.G1.phase.Ni1.B12        0.0
# crystal.G1.phase.Ni1.B21        0.0
# crystal.G1.phase.Ni1.B13        0.0
# crystal.G1.phase.Ni1.B31        0.0
# crystal.G1.phase.Ni1.B23        0.0
# crystal.G1.phase.Ni1.B32        0.0
# crystal.G1.phase.Ni1.Biso       0.09999999999999999
#
# crystal.G1.phase.Ni2.x          0.5
# crystal.G1.phase.Ni2.y          0.5
# crystal.G1.phase.Ni2.z          0.0
# crystal.G1.phase.Ni2.occupancy  1.0
# crystal.G1.phase.Ni2.occ        1.0
# crystal.G1.phase.Ni2.U11        0.0012665147955292222
# crystal.G1.phase.Ni2.U22        0.0012665147955292222
# crystal.G1.phase.Ni2.U33        0.0012665147955292222
# crystal.G1.phase.Ni2.U12        0.0
# crystal.G1.phase.Ni2.U21        0.0
# crystal.G1.phase.Ni2.U13        0.0
# crystal.G1.phase.Ni2.U31        0.0
# crystal.G1.phase.Ni2.U23        0.0
# crystal.G1.phase.Ni2.U32        0.0
# crystal.G1.phase.Ni2.Uiso       0.0012665147955292222
# crystal.G1.phase.Ni2.B11        0.09999999999999999
# crystal.G1.phase.Ni2.B22        0.09999999999999999
# crystal.G1.phase.Ni2.B33        0.09999999999999999
# crystal.G1.phase.Ni2.B12        0.0
# crystal.G1.phase.Ni2.B21        0.0
# crystal.G1.phase.Ni2.B13        0.0
# crystal.G1.phase.Ni2.B31        0.0
# crystal.G1.phase.Ni2.B23        0.0
# crystal.G1.phase.Ni2.B32        0.0
# crystal.G1.phase.Ni2.Biso       0.09999999999999999
#
# crystal.G1.phase.Ni3.x          0.5
# crystal.G1.phase.Ni3.y          0.0
# crystal.G1.phase.Ni3.z          0.5
# crystal.G1.phase.Ni3.occupancy  1.0
# crystal.G1.phase.Ni3.occ        1.0
# crystal.G1.phase.Ni3.U11        0.0012665147955292222
# crystal.G1.phase.Ni3.U22        0.0012665147955292222
# crystal.G1.phase.Ni3.U33        0.0012665147955292222
# crystal.G1.phase.Ni3.U12        0.0
# crystal.G1.phase.Ni3.U21        0.0
# crystal.G1.phase.Ni3.U13        0.0
# crystal.G1.phase.Ni3.U31        0.0
# crystal.G1.phase.Ni3.U23        0.0
# crystal.G1.phase.Ni3.U32        0.0
# crystal.G1.phase.Ni3.Uiso       0.0012665147955292222
# crystal.G1.phase.Ni3.B11        0.09999999999999999
# crystal.G1.phase.Ni3.B22        0.09999999999999999
# crystal.G1.phase.Ni3.B33        0.09999999999999999
# crystal.G1.phase.Ni3.B12        0.0
# crystal.G1.phase.Ni3.B21        0.0
# crystal.G1.phase.Ni3.B13        0.0
# crystal.G1.phase.Ni3.B31        0.0
# crystal.G1.phase.Ni3.B23        0.0
# crystal.G1.phase.Ni3.B32        0.0
# crystal.G1.phase.Ni3.Biso       0.09999999999999999
#
# Constraints
# ------------------------------------------------------------------------------
# crystal.G1.phase.Ni1.Uiso <-- Uiso_0
# crystal.G1.phase.Ni2.Uiso <-- Uiso_0
# crystal.G1.phase.Ni3.Uiso <-- Uiso_0
# crystal.G1.phase.lattice.b <-- a
# crystal.G1.phase.lattice.c <-- a
# None
# 1
# Obfuscated Reality Mappers (ORMs) can be useful database tools.

# %%
# Tell the Fit Recipe we want to write the maximum amount of
# information to the terminal during fitting.
recipe.fithooks[0].verbose = 3

# During the optimization, we fix and free parameters sequentially
# as you would in PDFgui. This leads to more stability in the refinement.
# We first fix all variables. "all" is a tag which incorporates
# every parameter.
recipe.fix("all")

# We then run a fit using the SciPy function "least_squares" which
# takes as its arguments the function to be optimized, here recipe.residual,
# as well as initial values for the fitted parameters, provided by
# recipe.values. The x_scale="jac" argument is an optional argument
# that provides for a bit more stability in the refinement.
# "least_squares" is a bit more robust than "leastsq,"
# which is another optimization function provided by SciPy.
# "least_squares" supports bounds on refined parameters,
#  while "leastsq" does not.

refine_params = ["scale", "lat", "adp", "inst","d2", "all"]

for params in refine_params:
    recipe.free(params)
    print(f"\n****\nFitting {recipe.getNames()} against "
          f"{GR_NAME} with {CIF_NAME}\n")
    input("\nPress enter to continue...")
    least_squares(recipe.residual, recipe.values, x_scale="jac")

print(pyjokes.get_joke())
# Out:
# ****
# Fitting ['s1'] against Ni.gr with Ni.cif
#
#
# Press enter to continue...
# 2
# Residual: 599.3747968141075
# Variables
#   s1 = 0.400000
# 3
# Residual: 599.3748604214591
# Variables
#   s1 = 0.400000
# 4
# Residual: 544.6648554532057
# Variables
#   s1 = 0.374366
# 5
# Residual: 544.6648554532243
# Variables
#   s1 = 0.374366
# 6
# Residual: 544.6648554532059
# Variables
#   s1 = 0.374366
#
# ****
# Fitting ['s1', 'fcc_Lat'] against Ni.gr with Ni.cif
#
#
# Press enter to continue...
# 7
# Residual: 544.6648554532059
# Variables
#   fcc_Lat = 3.520000
#   s1 = 0.374366
# 8
# Residual: 544.6648554532242
# Variables
#   fcc_Lat = 3.520000
#   s1 = 0.374366
# 9
# Residual: 544.6551553881741
# Variables
#   fcc_Lat = 3.520000
#   s1 = 0.374366
# 10
# Residual: 123.75033270570313
# Variables
#   fcc_Lat = 3.524026
#   s1 = 0.374821
# 11
# Residual: 123.75031596779941
# Variables
#   fcc_Lat = 3.524026
#   s1 = 0.374821
# 12
# Residual: 123.74916358428338
# Variables
#   fcc_Lat = 3.524026
#   s1 = 0.374821
# 13
# Residual: 113.83795302619913
# Variables
#   fcc_Lat = 3.524514
#   s1 = 0.381638
# 14
# Residual: 113.83795278493858
# Variables
#   fcc_Lat = 3.524514
#   s1 = 0.381638
# 15
# Residual: 113.83783582280506
# Variables
#   fcc_Lat = 3.524514
#   s1 = 0.381638
# 16
# Residual: 113.77859545190078
# Variables
#   fcc_Lat = 3.524561
#   s1 = 0.381741
# 17
# Residual: 113.77859544962513
# Variables
#   fcc_Lat = 3.524561
#   s1 = 0.381741
# 18
# Residual: 113.77858215859993
# Variables
#   fcc_Lat = 3.524561
#   s1 = 0.381741
# 19
# Residual: 113.77783915144306
# Variables
#   fcc_Lat = 3.524567
#   s1 = 0.381742
# 20
# Residual: 113.77783915143225
# Variables
#   fcc_Lat = 3.524567
#   s1 = 0.381742
# 21
# Residual: 113.77783769364794
# Variables
#   fcc_Lat = 3.524567
#   s1 = 0.381742
# 22
# Residual: 113.77782937567949
# Variables
#   fcc_Lat = 3.524567
#   s1 = 0.381743
# 23
# Residual: 113.77782937569752
# Variables
#   fcc_Lat = 3.524567
#   s1 = 0.381743
# 24
# Residual: 113.77782926749619
# Variables
#   fcc_Lat = 3.524567
#   s1 = 0.381743
# 25
# Residual: 113.77782925733024
# Variables
#   fcc_Lat = 3.524567
#   s1 = 0.381743
# 26
# Residual: 113.77782925734867
# Variables
#   fcc_Lat = 3.524567
#   s1 = 0.381743
# 27
# Residual: 113.77782930305798
# Variables
#   fcc_Lat = 3.524567
#   s1 = 0.381743
#
# ****
# Fitting ['s1', 'fcc_Lat', 'fcc_ADP'] against Ni.gr with Ni.cif
#
#
# Press enter to continue...
# 28
# Residual: 113.77782930305798
# Variables
#   fcc_ADP = 0.005000
#   fcc_Lat = 3.524567
#   s1 = 0.381743
# 29
# Residual: 113.77782930306132
# Variables
#   fcc_ADP = 0.005000
#   fcc_Lat = 3.524567
#   s1 = 0.381743
# 30
# Residual: 113.77782946490508
# Variables
#   fcc_ADP = 0.005000
#   fcc_Lat = 3.524567
#   s1 = 0.381743
# 31
# Residual: 113.77548402550329
# Variables
#   fcc_ADP = 0.005000
#   fcc_Lat = 3.524567
#   s1 = 0.381743
# 32
# Residual: 58.98014467576906
# Variables
#   fcc_ADP = 0.005704
#   fcc_Lat = 3.524575
#   s1 = 0.409382
# 33
# Residual: 58.98014420965881
# Variables
#   fcc_ADP = 0.005704
#   fcc_Lat = 3.524575
#   s1 = 0.409382
# 34
# Residual: 58.980172208519974
# Variables
#   fcc_ADP = 0.005704
#   fcc_Lat = 3.524575
#   s1 = 0.409382
# 35
# Residual: 58.98006453096494
# Variables
#   fcc_ADP = 0.005704
#   fcc_Lat = 3.524575
#   s1 = 0.409382
# 36
# Residual: 58.85375814777541
# Variables
#   fcc_ADP = 0.005741
#   fcc_Lat = 3.524563
#   s1 = 0.410976
# 37
# Residual: 58.853758145519315
# Variables
#   fcc_ADP = 0.005741
#   fcc_Lat = 3.524563
#   s1 = 0.410976
# 38
# Residual: 58.853760966155384
# Variables
#   fcc_ADP = 0.005741
#   fcc_Lat = 3.524563
#   s1 = 0.410976
# 39
# Residual: 58.853759150011584
# Variables
#   fcc_ADP = 0.005741
#   fcc_Lat = 3.524563
#   s1 = 0.410976
# 40
# Residual: 58.85371574612494
# Variables
#   fcc_ADP = 0.005741
#   fcc_Lat = 3.524561
#   s1 = 0.410965
# 41
# Residual: 58.853715746140104
# Variables
#   fcc_ADP = 0.005741
#   fcc_Lat = 3.524561
#   s1 = 0.410965
# 42
# Residual: 58.85371593689139
# Variables
#   fcc_ADP = 0.005741
#   fcc_Lat = 3.524561
#   s1 = 0.410965
# 43
# Residual: 58.85371576405203
# Variables
#   fcc_ADP = 0.005741
#   fcc_Lat = 3.524561
#   s1 = 0.410965
# 44
# Residual: 58.85371565438851
# Variables
#   fcc_ADP = 0.005741
#   fcc_Lat = 3.524561
#   s1 = 0.410965
# 45
# Residual: 58.853715654404475
# Variables
#   fcc_ADP = 0.005741
#   fcc_Lat = 3.524561
#   s1 = 0.410965
# 46
# Residual: 58.85371571934868
# Variables
#   fcc_ADP = 0.005741
#   fcc_Lat = 3.524561
#   s1 = 0.410965
# 47
# Residual: 58.85371569576756
# Variables
#   fcc_ADP = 0.005741
#   fcc_Lat = 3.524561
#   s1 = 0.410965
#
# ****
# Fitting ['s1', 'Calib_Qdamp', 'Calib_Qbroad', 'fcc_Lat', 'fcc_ADP'] against Ni.gr with Ni.cif
#
#
# Press enter to continue...
# 48
# Residual: 58.85371569576756
# Variables
#   Calib_Qbroad = 0.020000
#   Calib_Qdamp = 0.040000
#   fcc_ADP = 0.005741
#   fcc_Lat = 3.524561
#   s1 = 0.410965
# 49
# Residual: 58.853715694591656
# Variables
#   Calib_Qbroad = 0.020000
#   Calib_Qdamp = 0.040000
#   fcc_ADP = 0.005741
#   fcc_Lat = 3.524561
#   s1 = 0.410965
# 50
# Residual: 58.853390748864754
# Variables
#   Calib_Qbroad = 0.020000
#   Calib_Qdamp = 0.040000
#   fcc_ADP = 0.005741
#   fcc_Lat = 3.524561
#   s1 = 0.410965
# 51
# Residual: 58.8536225230413
# Variables
#   Calib_Qbroad = 0.020000
#   Calib_Qdamp = 0.040000
#   fcc_ADP = 0.005741
#   fcc_Lat = 3.524561
#   s1 = 0.410965
# 52
# Residual: 58.85371576144386
# Variables
#   Calib_Qbroad = 0.020000
#   Calib_Qdamp = 0.040000
#   fcc_ADP = 0.005741
#   fcc_Lat = 3.524561
#   s1 = 0.410965
# 53
# Residual: 58.85371548629772
# Variables
#   Calib_Qbroad = 0.020000
#   Calib_Qdamp = 0.040000
#   fcc_ADP = 0.005741
#   fcc_Lat = 3.524561
#   s1 = 0.410965
# 54
# Residual: 10.833224464135888
# Variables
#   Calib_Qbroad = 0.017102
#   Calib_Qdamp = 0.045182
#   fcc_ADP = 0.005878
#   fcc_Lat = 3.524563
#   s1 = 0.434715
# 55
# Residual: 10.833221157989145
# Variables
#   Calib_Qbroad = 0.017102
#   Calib_Qdamp = 0.045182
#   fcc_ADP = 0.005878
#   fcc_Lat = 3.524563
#   s1 = 0.434715
# 56
# Residual: 10.83324007117454
# Variables
#   Calib_Qbroad = 0.017102
#   Calib_Qdamp = 0.045182
#   fcc_ADP = 0.005878
#   fcc_Lat = 3.524563
#   s1 = 0.434715
# 57
# Residual: 10.833232998235419
# Variables
#   Calib_Qbroad = 0.017102
#   Calib_Qdamp = 0.045182
#   fcc_ADP = 0.005878
#   fcc_Lat = 3.524563
#   s1 = 0.434715
# 58
# Residual: 10.833187576957432
# Variables
#   Calib_Qbroad = 0.017102
#   Calib_Qdamp = 0.045182
#   fcc_ADP = 0.005878
#   fcc_Lat = 3.524563
#   s1 = 0.434715
# 59
# Residual: 10.833380410991838
# Variables
#   Calib_Qbroad = 0.017102
#   Calib_Qdamp = 0.045182
#   fcc_ADP = 0.005878
#   fcc_Lat = 3.524563
#   s1 = 0.434715
# 60
# Residual: 10.599733721152717
# Variables
#   Calib_Qbroad = 0.016720
#   Calib_Qdamp = 0.045298
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436584
# 61
# Residual: 10.599733707143741
# Variables
#   Calib_Qbroad = 0.016720
#   Calib_Qdamp = 0.045298
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436584
# 62
# Residual: 10.599733915218708
# Variables
#   Calib_Qbroad = 0.016720
#   Calib_Qdamp = 0.045298
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436584
# 63
# Residual: 10.59973377897071
# Variables
#   Calib_Qbroad = 0.016720
#   Calib_Qdamp = 0.045298
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436584
# 64
# Residual: 10.59973407864076
# Variables
#   Calib_Qbroad = 0.016720
#   Calib_Qdamp = 0.045298
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436584
# 65
# Residual: 10.599734095677077
# Variables
#   Calib_Qbroad = 0.016720
#   Calib_Qdamp = 0.045298
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436584
# 66
# Residual: 10.5997213838066
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436589
# 67
# Residual: 10.599721383820794
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436590
# 68
# Residual: 10.599721388147127
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436589
# 69
# Residual: 10.599721385679212
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436589
# 70
# Residual: 10.599721459074765
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436589
# 71
# Residual: 10.59972142674307
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436589
# 72
# Residual: 10.599721372843053
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436589
# 73
# Residual: 10.599721372857267
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436589
# 74
# Residual: 10.599721373880582
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436589
# 75
# Residual: 10.599721373054402
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436589
# 76
# Residual: 10.599721425394822
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436589
# 77
# Residual: 10.59972141236669
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436589
#
# ****
# Fitting ['s1', 'Ni_Delta2', 'Calib_Qdamp', 'Calib_Qbroad', 'fcc_Lat', 'fcc_ADP'] against Ni.gr with Ni.cif
#
#
# Press enter to continue...
# 78
# Residual: 10.59972141236669
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   Ni_Delta2 = 2.000000
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436589
# 79
# Residual: 10.599721411284811
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   Ni_Delta2 = 2.000000
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436589
# 80
# Residual: 10.599721442250903
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   Ni_Delta2 = 2.000000
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436589
# 81
# Residual: 10.599721418837898
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   Ni_Delta2 = 2.000000
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436589
# 82
# Residual: 10.59972141610109
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   Ni_Delta2 = 2.000000
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436589
# 83
# Residual: 10.599721465632669
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   Ni_Delta2 = 2.000000
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436589
# 84
# Residual: 10.599721531956009
# Variables
#   Calib_Qbroad = 0.016719
#   Calib_Qdamp = 0.045297
#   Ni_Delta2 = 2.000000
#   fcc_ADP = 0.005884
#   fcc_Lat = 3.524583
#   s1 = 0.436589
# 85
# Residual: 10.578576800443491
# Variables
#   Calib_Qbroad = 0.016806
#   Calib_Qdamp = 0.045299
#   Ni_Delta2 = 1.955733
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436691
# 86
# Residual: 10.57857680153829
# Variables
#   Calib_Qbroad = 0.016806
#   Calib_Qdamp = 0.045299
#   Ni_Delta2 = 1.955733
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436691
# 87
# Residual: 10.57857679899765
# Variables
#   Calib_Qbroad = 0.016806
#   Calib_Qdamp = 0.045299
#   Ni_Delta2 = 1.955733
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436691
# 88
# Residual: 10.578576742858779
# Variables
#   Calib_Qbroad = 0.016806
#   Calib_Qdamp = 0.045299
#   Ni_Delta2 = 1.955733
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436691
# 89
# Residual: 10.578576766003678
# Variables
#   Calib_Qbroad = 0.016806
#   Calib_Qdamp = 0.045299
#   Ni_Delta2 = 1.955733
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436691
# 90
# Residual: 10.57857629161368
# Variables
#   Calib_Qbroad = 0.016806
#   Calib_Qdamp = 0.045299
#   Ni_Delta2 = 1.955733
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436691
# 91
# Residual: 10.578577101304067
# Variables
#   Calib_Qbroad = 0.016806
#   Calib_Qdamp = 0.045299
#   Ni_Delta2 = 1.955733
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436691
# 92
# Residual: 10.578529578486691
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957628
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436675
# 93
# Residual: 10.578529578500586
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957628
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436675
# 94
# Residual: 10.578529578565206
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957628
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436675
# 95
# Residual: 10.578529578436353
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957628
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436675
# 96
# Residual: 10.578529578454702
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957628
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436675
# 97
# Residual: 10.578529632017425
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957628
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436675
# 98
# Residual: 10.578529603856595
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957628
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436675
# 99
# Residual: 10.57852943132915
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957513
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 100
# Residual: 10.578529431343364
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957513
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 101
# Residual: 10.578529431325036
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957513
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 102
# Residual: 10.578529432083673
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957513
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 103
# Residual: 10.578529431414779
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957513
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 104
# Residual: 10.578529482159608
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957513
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 105
# Residual: 10.578529472204501
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957513
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 106
# Residual: 10.578529431003972
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957519
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 107
# Residual: 10.57852943101818
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957519
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 108
# Residual: 10.578529431004137
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957519
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 109
# Residual: 10.57852943189942
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957519
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 110
# Residual: 10.578529431162423
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957519
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 111
# Residual: 10.57852948294375
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957519
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 112
# Residual: 10.578529470798362
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957519
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
#
# ****
# Fitting ['s1', 'Ni_Delta2', 'Calib_Qdamp', 'Calib_Qbroad', 'fcc_Lat', 'fcc_ADP'] against Ni.gr with Ni.cif
#
#
# Press enter to continue...
# 113
# Residual: 10.578529470798362
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957519
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 114
# Residual: 10.578529469714779
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957519
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 115
# Residual: 10.57852947077975
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957519
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 116
# Residual: 10.578529477134973
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957519
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 117
# Residual: 10.578529474498735
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957519
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 118
# Residual: 10.578529523450916
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957519
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 119
# Residual: 10.578529590921857
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957519
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 120
# Residual: 10.578529431014095
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 121
# Residual: 10.578529431028308
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 122
# Residual: 10.57852943101451
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 123
# Residual: 10.578529431929221
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 124
# Residual: 10.578529431142346
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 125
# Residual: 10.578529482349905
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 126
# Residual: 10.578529470195065
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# How many QAs does it take to change a lightbulb? They noticed that the room was dark. They don't fix problems, they find them.

# %%
# We use the savetxt method of the profile to write a text file
# containing the measured and fitted PDF to disk.
# The file is named based on the basename we created earlier, and
# written to the fitdir directory.
profile = recipe.crystal.profile
profile.savetxt(fitdir / (basename + ".fit"))

# We use the FitResults function to parse out the results from
# the optimized Fit Recipe.
res = FitResults(recipe)

# We print these results to the terminal.
res.printResults()

print(pyjokes.get_joke())
# Out:
# 127
# Residual: 10.57852946987458
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 128
# Residual: 10.578529470517983
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 129
# Residual: 10.57852947018223
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 130
# Residual: 10.578529470207718
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 131
# Residual: 10.578529470362216
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 132
# Residual: 10.578529470029538
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 133
# Residual: 10.578529470234777
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 134
# Residual: 10.57852947015552
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 135
# Residual: 10.57852949366164
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 136
# Residual: 10.578529493505991
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 137
# Residual: 10.578529470509105
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 138
# Residual: 10.578529469883375
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# 139
# Residual: 10.578529469883375
# Variables
#   Calib_Qbroad = 0.016809
#   Calib_Qdamp = 0.045298
#   Ni_Delta2 = 1.957518
#   fcc_ADP = 0.005876
#   fcc_Lat = 3.524583
#   s1 = 0.436676
# Some quantities invalid due to missing profile uncertainty
# Overall (Chi2 and Reduced Chi2 invalid)
# ------------------------------------------------------------------------------
# Residual       10.57852947
# Contributions  10.57852947
# Restraints     0.00000000
# Chi2           10.57852947
# Reduced Chi2   0.00218339
# Rw             0.02942970
#
# Variables (Uncertainties invalid)
# ------------------------------------------------------------------------------
# Calib_Qbroad  1.68085929e-02 +/- 2.59401886e-03
# Calib_Qdamp   4.52977361e-02 +/- 9.58281630e-04
# Ni_Delta2     1.95751844e+00 +/- 3.00262586e-01
# fcc_ADP       5.87582327e-03 +/- 1.65381074e-04
# fcc_Lat       3.52458308e+00 +/- 2.30476560e-04
# s1            4.36675960e-01 +/- 7.47794411e-03
#
# Variable Correlations greater than 25% (Correlations invalid)
# ------------------------------------------------------------------------------
# corr(Calib_Qbroad, fcc_ADP)       -0.7338
# corr(Calib_Qdamp, Calib_Qbroad)   -0.7333
# corr(s1, fcc_ADP)                 0.6691
# corr(s1, Calib_Qdamp)             0.6286
# corr(Calib_Qdamp, fcc_ADP)        0.4992
# corr(s1, Calib_Qbroad)            -0.4562
# corr(Ni_Delta2, fcc_ADP)          0.3226
# Eight bytes walk into a bar. The bartender asks, 'Can I get you anything?' 'Yeah,' replies the bytes. 'Make us a double.'

# %%
# We grab the fit Rw
rw = res.rw

# We use the saveResults method of FitResults to write a text file
# containing the fitted parameters and fit quality indices to disk.
# The file is named based on the basename we created earlier, and
# written to the resdir directory.
header = "crystal_HF.\n"
res.saveResults(resdir / (basename + ".res"), header=header)

# We use the plotresults function we created earlier to make a plot of
# the measured, calculated, and difference curves. We show this
# as an interactive window and then write a pdf file to disk.
# The file is named based on the basename we created earlier, and
# written to the figdir directory.
plotresults(recipe, figdir / basename)
# plt.ion()

print(pyjokes.get_joke())
# Out:
# A programmer crashes a car at the bottom of a hill, a bystander asks what happened, he says "No idea. Let's push it back up and try again".

# %%
# Let make a dictionary to hold our results. This way make reloading the
# fit parameters easier later
refined_dict = dict()

refined_dict['rw'] = rw.item()

recipe.free("all")
# We loop over the variable names, the variable values, and the variable uncertainties (esd)
for name, val, unc in zip(res.varnames, res.varvals, res.varunc):
    # We store the refined value for this variable using the "value" key.
    # We use the ".item()" method because "res.varvals" exist as
    # numpy.float64 objects, and we want them as regular python floats.
    if name not in refined_dict:
        refined_dict[name] = dict()
    refined_dict[name]["value"] = val.item()
    refined_dict[name]["uncert"] = unc.item()

with open(basename + ".yml", 'w') as outfile:
    yaml.safe_dump(refined_dict, outfile)

print(pyjokes.get_joke())
# Out:
# Schrodinger's attitude to web development: If I don't look at it in Internet Explorer then there's a chance it looks fine.
